# %%
# !git clone -b v6.2 https://github.com/ultralytics/yolov5.git

# %%
# !pip install -r /kaggle/working/yolov5/requirements.txt

# %%
import torch 
import os
from IPython.display import Image, clear_output

# %%
os.environ["DATASET_DIRECTORY"] = "/kaggle/working/datasets"

# %%
# %cd /kaggle/working/yolov5

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="FiClSc1HbNtFsrOBCwGO")
project = rf.workspace("hoangnhatvu").project("lvtn-oqur4")
dataset = project.version(2).download("yolov5")

# %%
# !python train.py --img 640 --batch 80 --epochs 250 --data {dataset.location}/data.yaml --weights yolov5s.pt --cache

# %%
# %ls /kaggle/working/yolov5/runs/train/

# %%
import shutil
shutil.make_archive("/kaggle/working/results", "zip", "/kaggle/working/yolov5/runs/train/")

# %% [markdown]
# ## ***Prediction***

# %%
# %cd /kaggle/working/yolov5
# !python detect.py --weights runs/train/exp/weights/best.pt --img 640 --conf 0.2 --source /kaggle/input/grapee

# %%
import glob
from IPython.display import Image, display

i = 0
for imgName in glob.glob("/kaggle/working/yolov5/runs/detect/exp/*.jpg"):
    i += 1
    if i < 10:
        display(Image(filename=imgName))
        print("\n")
